# %%
# Визначення номера завдання для 27-го у списку з 15 основних завдань
# Завдання обчислюється циклічно
task_list_size = 15
your_position_on_list = 27

# Номер завдання, оскільки позиція 1 є першим завданням, а не нульовою
your_assigned_task_number = (your_position_on_list - 1) % task_list_size + 1

# Перевірка, чи номер завдання співпадає з 12, як у прикладі
# print(f"Ваше завдання №: {your_assigned_task_number}") # Для перевірки, можна розкоментувати

solutions = {
    "assigned_task": {
        "task_number": your_assigned_task_number,
        "problem": "Задано функцію $f(n) = 200n^3 + 15$ і $g(n) = n^3$. Доведіть, що $f(n) = O(g(n))$.",
        "solution": {
            "proof_steps": [
                "Щоб довести, що $f(n) = O(g(n))$, нам потрібно знайти додатні константи $c$ та $n_0$ такі, що $f(n) \le c \cdot g(n)$ для всіх $n \ge n_0$.",
                "Дано: $f(n) = 200n^3 + 15$ і $g(n) = n^3$.",
                "Ми хочемо знайти $c$ та $n_0$ такі, що $200n^3 + 15 \le c \cdot n^3$.",
                "Розділимо обидві сторони на $n^3$ (для $n > 0$): $200 + \\frac{15}{n^3} \\le c$.",
                "Оскільки $n$ збільшується, $\\frac{15}{n^3}$ наближається до 0. Для $n \\ge 1$, $\\frac{15}{n^3}$ є додатним.",
                "Ми можемо вибрати $c$ трохи більше 200. Наприклад, нехай $c = 201$.",
                "Тоді нам потрібно, щоб $200n^3 + 15 \le 201n^3$.",
                "Віднімаємо $200n^3$ з обох сторін: $15 \le n^3$.",
                "Беремо кубічний корінь з обох сторін: $n \\ge \\sqrt[3]{15}$.",
                "Оскільки $\\sqrt[3]{15} \\approx 2.466$, ми можемо вибрати $n_0 = 3$.",
                "Таким чином, для $c = 201$ та $n_0 = 3$, $200n^3 + 15 \le 201n^3$ для всіх $n \\ge 3$.",
                "Це доводить, що $f(n) = O(g(n))$.",
                "Константи: $c = 201$, $n_0 = 3$"
            ],
            "conclusion": "$f(n) = O(g(n))$ є істинним, оскільки знайдені константи $c$ та $n_0$ задовольняють визначення."
        }
    },
    "control_questions": [
        {
            "question_number": 1,
            "question": "Що таке асимптотична складність алгоритму?",
            "answer": "Асимптотична складність алгоритму описує поведінку часу виконання або простору пам'яті алгоритму при збільшенні розміру вхідних даних ($n$) до нескінченності. Вона дозволяє порівнювати ефективність алгоритмів незалежно від апаратної чи програмної реалізації."
        },
        {
            "question_number": 2,
            "question": "Яким чином визначається O-нотація і яка її сутність?",
            "answer": "O-нотація (Big O notation) визначається як: $f(n) = O(g(n))$ тоді і тільки тоді, якщо існують додатні константи $c$ та $n_0$ такі, що $0 \\le f(n) \\le c \\cdot g(n)$ для всіх $n \\ge n_0$. \n\nСутність O-нотації полягає в тому, щоб забезпечити верхню межу (upper bound) швидкості росту функції. Вона дозволяє ігнорувати константні фактори та менш значущі члени полінома, зосереджуючись на домінуючому члені, який визначає поведінку функції при великих $n$."
        },
        {
            "question_number": 3,
            "question": "Які основні правила використання O-нотації при аналізі алгоритмів?",
            "answer": "Основні правила використання O-нотації при аналізі алгоритмів:\n1. **Видалення константних множників:** $O(c \\cdot f(n)) = O(f(n))$, де $c$ - константа (наприклад, $O(5n^2) = O(n^2)$).\n2. **Видалення менш значущих членів:** Якщо функція є сумою членів, залишається лише той член, який має найвищий порядок росту (наприклад, $O(n^2 + n) = O(n^2)$).\n3. **Правило суми:** Якщо $f_1(n) = O(g_1(n))$ і $f_2(n) = O(g_2(n))$, то $f_1(n) + f_2(n) = O(\\max(g_1(n), g_2(n)))$.\n4. **Правило добутку:** Якщо $f_1(n) = O(g_1(n))$ і $f_2(n) = O(g_2(n))$, то $f_1(n) \\cdot f_2(n) = O(g_1(n) \\cdot g_2(n))$.\n5. **Логарифмічні функції:** $\\log_b n$ є $O(\\log n)$ для будь-якої константи $b > 1$. База логарифма не має значення в O-нотації."
        },
        {
            "question_number": 4,
            "question": "Що означають вирази $O(1), O(n), O(n^2)$ в контексті асимптотичної складності?",
            "answer": "Ці вирази представляють різні порядки асимптотичної складності:\n- **$O(1)$ (константна складність):** Означає, що час виконання або використовувана пам'ять алгоритму залишаються постійними, незалежно від розміру вхідних даних ($n$). Наприклад, доступ до елемента масиву за індексом.\n- **$O(n)$ (лінійна складність):** Означає, що час виконання або використовувана пам'ять алгоритму зростають лінійно з розміром вхідних даних ($n$). Наприклад, перебір всіх елементів у списку.\n- **$O(n^2)$ (квадратична складність):** Означає, що час виконання або використовувана пам'ять алгоритму зростають пропорційно квадрату розміру вхідних даних ($n$). Наприклад, вкладені цикли, де кожен цикл проходить по всіх елементах."
        },
        {
            "question_number": 5,
            "question": "Яким чином визначити асимптотичну складність алгоритму за його кодом або математичним виразом?",
            "answer": "Визначити асимптотичну складність алгоритму можна наступними способами:\n1. **Підрахунок операцій (для коду):**\n    - Визначте основні операції, які виконуються в алгоритмі (наприклад, присвоєння, порівняння, арифметичні операції, доступ до елементів).\n    - Проаналізуйте цикли: Один цикл, що проходить $n$ разів, зазвичай дає $O(n)$. Вкладені цикли, де внутрішній цикл також проходить $n$ разів, дають $O(n^2)$.\n    - Проаналізуйте рекурсивні виклики: Використовуйте майстер-теорему або дерево рекурсії, щоб визначити складність.\n    - Проаналізуйте умовні оператори (if/else): Розгляньте найгірший випадок.\n    - Ігноруйте константи: $O(2n)$ стає $O(n)$.\n    - Ігноруйте менш значущі члени: $O(n^2 + n + 1)$ стає $O(n^2)$.\n2. **Аналіз математичного виразу:**\n    - Якщо складність виражена математичною функцією $f(n)$ (наприклад, кількість операцій), то асимптотична складність буде $O(g(n))$, де $g(n)$ - це член з найвищим порядком росту в $f(n)$ після відкидання констант і менш значущих членів.\n    - Наприклад, якщо кількість операцій $T(n) = 3n^3 + 100n \\log n + 500$, то асимптотична складність буде $O(n^3)$, оскільки $n^3$ росте швидше, ніж $n \\log n$ або константа."
        }
    ]
}

# Для зручності виведення у форматі JSON
import json
print(json.dumps(solutions, indent=4, ensure_ascii=False))
