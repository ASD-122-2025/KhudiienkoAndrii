# %%
# Your position on the list
your_position_on_list = 27
task_list_size = 15

# Calculate the assigned task numbers based on the rule: n and n+5
# The formula (position - 1) % total_tasks + 1 handles the 1-based indexing and cyclic nature
assigned_task_1_number = ((your_position_on_list - 1) % task_list_size) + 1
assigned_task_2_number = (((your_position_on_list + 5) - 1) % task_list_size) + 1

solutions = {
    "assigned_tasks": [
        {
            "task_number": assigned_task_1_number,
            "type": "O-нотація (верхня межа) методом меж",
            "problem": "Дано функції $f(n) = n^2 + 3n + 10$ і $g(n) = n^4$. Показати, що $f(n) = O(g(n))$, використовуючи метод меж.",
            "solution": {
                "method": "Метод меж (Limit Method)",
                "proof_steps": [
                    "Щоб показати, що $f(n) = O(g(n))$ за допомогою методу меж, ми обчислюємо границю $\\lim_{n \\to \\infty} \\frac{f(n)}{g(n)}$.",
                    "Якщо границя дорівнює кінцевій константі $L \\ge 0$, то $f(n) = O(g(n))$.",
                    "Дано: $f(n) = n^2 + 3n + 10$ і $g(n) = n^4$.",
                    "Обчислимо границю:",
                    "$\\lim_{n \\to \\infty} \\frac{n^2 + 3n + 10}{n^4}$",
                    "Розділимо кожен член чисельника на $n^4$:",
                    "$= \\lim_{n \\to \\infty} (\\frac{n^2}{n^4} + \\frac{3n}{n^4} + \\frac{10}{n^4})$",
                    "$= \\lim_{n \\to \\infty} (\\frac{1}{n^2} + \\frac{3}{n^3} + \\frac{10}{n^4})$",
                    "При $n \\to \\infty$, кожен член дробу наближається до 0:",
                    "$= 0 + 0 + 0 = 0$",
                    "Оскільки границя $L = 0$ (кінцева константа $\\ge 0$), то $f(n) = O(g(n))$.",
                    "Це означає, що $f(n)$ росте не швидше, ніж $g(n)$."
                ],
                "conclusion": "Отже, $f(n) = O(g(n))$ доведено методом меж."
            }
        },
        {
            "task_number": assigned_task_2_number,
            "type": "$\Omega$-нотація (нижня межа) методом визначення",
            "problem": "Маємо дві функції $f(n) = 4n^3 - 12n + 9$ і $g(n) = n^3$. Довести, що $f(n) = \\Omega(g(n))$.",
            "solution": {
                "method": "За визначенням $\\Omega$-нотації",
                "proof_steps": [
                    "Щоб довести, що $f(n) = \\Omega(g(n))$, нам потрібно знайти додатні константи $c$ та $n_0$ такі, що $f(n) \\ge c \\cdot g(n)$ для всіх $n \\ge n_0$.",
                    "Дано: $f(n) = 4n^3 - 12n + 9$ і $g(n) = n^3$.",
                    "Ми хочемо знайти $c$ та $n_0$ такі, що $4n^3 - 12n + 9 \\ge c \\cdot n^3$.",
                    "Розглянемо нерівність. Щоб знайти $c$, можна спробувати знайти $n_0$ таким, щоб $4n^3 - 12n + 9$ було більшим за $c \cdot n^3$.",
                    "Для великих $n$, домінуючий член $4n^3$ визначає поведінку $f(n)$.",
                    "Спробуємо вибрати $c$ менше 4, наприклад $c = 1$.",
                    "Тоді нам потрібно, щоб $4n^3 - 12n + 9 \\ge 1 \\cdot n^3$.",
                    "Звідси $3n^3 - 12n + 9 \\ge 0$.",
                    "Розділимо на $3$: $n^3 - 4n + 3 \\ge 0$.",
                    "Можна перевірити невеликі значення $n$.",
                    "При $n=1: 1 - 4 + 3 = 0$. Нерівність виконується (рівність).",
                    "При $n=2: 8 - 8 + 3 = 3 \\ge 0$. Нерівність виконується.",
                    "При $n=3: 27 - 12 + 3 = 18 \\ge 0$. Нерівність виконується.",
                    "Функція $h(n) = n^3 - 4n + 3$ зростає для $n \\ge 2$ (похідна $3n^2 - 4$ є додатною для $n > \\sqrt{4/3} \\approx 1.15$).",
                    "Отже, ми можемо вибрати $c=1$ та $n_0=1$.",
                    "Для $c=1$ та $n_0=1$, $4n^3 - 12n + 9 \\ge 1 \\cdot n^3$ для всіх $n \\ge 1$.",
                    "Це доводить, що $f(n) = \\Omega(g(n))$.",
                    "Константи: $c = 1$, $n_0 = 1$"
                ],
                "conclusion": "Отже, $f(n) = \\Omega(g(n))$ доведено за визначенням."
            }
        }
    ],
    "control_questions": [
        {
            "question_number": 1,
            "question": "Що таке асимптотична складність алгоритму?",
            "answer": "Асимптотична складність алгоритму описує поведінку часу виконання або простору пам'яті алгоритму при збільшенні розміру вхідних даних ($n$) до нескінченності. Вона дозволяє оцінити, наскільки ефективно алгоритм масштабується з ростом обсягу даних, і порівнювати алгоритми незалежно від конкретної реалізації чи апаратного забезпечення."
        },
        {
            "question_number": 2,
            "question": "Які інші нотації, крім О-нотації, використовуються для вираження асимптотичної складності?",
            "answer": "Крім O-нотації (Big O), для вираження асимптотичної складності використовуються:\n- **$\\Omega$-нотація (Big Omega):** $f(n) = \\Omega(g(n))$ означає, що $g(n)$ є асимптотичною нижньою межею для $f(n)$. Тобто, $f(n)$ росте не повільніше, ніж $g(n)$.\n- **$\\Theta$-нотація (Big Theta):** $f(n) = \\Theta(g(n))$ означає, що $g(n)$ є асимптотично точною межею для $f(n)$. Тобто, $f(n)$ росте з тією ж швидкістю, що й $g(n)$. Це означає, що $f(n)$ є одночасно $O(g(n))$ і $\\Omega(g(n))$.\n- **$o$-нотація (Little O):** $f(n) = o(g(n))$ означає, що $g(n)$ є строгою асимптотичною верхньою межею для $f(n)$. Тобто, $f(n)$ росте значно повільніше, ніж $g(n)$ (\\$\\lim_{n \\to \\infty} f(n)/g(n) = 0$).\n- **$\\omega$-нотація (Little Omega):** $f(n) = \\omega(g(n))$ означає, що $g(n)$ є строгою асимптотичною нижньою межею для $f(n)$. Тобто, $f(n)$ росте значно швидше, ніж $g(n)$ (\\$\\lim_{n \\to \\infty} f(n)/g(n) = \\infty$).\n- **$O^*$ (Big O Star) або $\\tilde{O}$ (Soft O):** Використовується для ігнорування логарифмічних факторів. Наприклад, $O(n \\log n)$ може бути записано як $\\tilde{O}(n)$. Це спрощує аналіз, коли логарифмічні члени вважаються менш значущими."
        },
        {
            "question_number": 3,
            "question": "Як визначити асимптотичну складність алгоритму за допомогою символів $\\Theta$ і $\\Omega$?",
            "answer": "Визначення асимптотичної складності за допомогою $\\Theta$ і $\\Omega$:\n\n**Для $\\Theta$-нотації (точна межа):**\nЩоб показати, що $f(n) = \\Theta(g(n))$, потрібно довести, що $f(n)$ є як $O(g(n))$, так і $\\Omega(g(n))$.\nЦе означає, що існують додатні константи $c_1, c_2$ та $n_0$ такі, що $0 \\le c_1 \\cdot g(n) \\le f(n) \\le c_2 \\cdot g(n)$ для всіх $n \\ge n_0$.\nНа практиці, якщо $\\lim_{n \\to \\infty} \\frac{f(n)}{g(n)} = L$, де $L$ - кінцева додатна константа ($L > 0$), то $f(n) = \\Theta(g(n))$.\n\n**Для $\\Omega$-нотації (нижня межа):**\nЩоб показати, що $f(n) = \\Omega(g(n))$, потрібно знайти додатні константи $c$ та $n_0$ такі, що $f(n) \\ge c \\cdot g(n)$ для всіх $n \\ge n_0$.\nНа практиці, якщо $\\lim_{n \\to \\infty} \\frac{f(n)}{g(n)} = L$, де $L$ - кінцева додатна константа ($L > 0$) або $L = \\infty$, то $f(n) = \\Omega(g(n))$. Це означає, що $f(n)$ росте принаймні так само швидко, як $g(n)$."
        },
        {
            "question_number": 4,
            "question": "Яка різниця між О-нотацією, $\\Theta$-нотацією і $\\Omega$-нотацією?",
            "answer": "Різниця між О-нотацією, $\\Theta$-нотацією і $\\Omega$-нотацією полягає в типі асимптотичної межі, яку вони представляють:\n- **O-нотація (Big O):** Надає **верхню межу** (upper bound) для часу виконання або простору пам'яті алгоритму. Вона говорить, що функція росте **не швидше**, ніж деяка інша функція. Це оцінка найгіршого випадку.\n  *Приклад: $3n = O(n^2)$ (тому що $3n$ росте не швидше, ніж $n^2$)*\n\n- **$\\Omega$-нотація (Big Omega):** Надає **нижню межу** (lower bound). Вона говорить, що функція росте **не повільніше**, ніж деяка інша функція. Це оцінка найкращого випадку (або гарантованого мінімального росту).\n  *Приклад: $n^2 = \\Omega(n)$ (тому що $n^2$ росте не повільніше, ніж $n$)*\n\n- **$\\Theta$-нотація (Big Theta):** Надає **точну (тугу) межу** (tight bound). Вона говорить, що функція росте **з тією ж швидкістю** (за порядком), що й деяка інша функція. Це означає, що функція є одночасно і верхньою, і нижньою межею.\n  *Приклад: $3n^2 + 5n = \\Theta(n^2)$ (тому що $3n^2 + 5n$ росте як $n^2$, не швидше і не повільніше)*"
        },
        {
            "question_number": 5,
            "question": "Які основні властивості інших нотацій, таких як $o$ (маленька o), $\\omega$ (маленька омега) та $O^*$ (маленька о з верхнім індексом)?",
            "answer": "Ось основні властивості інших нотацій:\n\n- **$o$-нотація (Little O):**\n  - **Властивість:** $f(n) = o(g(n))$ означає, що $f(n)$ росте **значно повільніше**, ніж $g(n)$. Формально, $\\lim_{n \\to \\infty} \\frac{f(n)}{g(n)} = 0$.\n  - **Сутність:** Це строга верхня межа. Якщо $f(n) = o(g(n))$, то $f(n) = O(g(n))$, але не навпаки. Це означає, що $f(n)$ ніколи не буде рости так само швидко, як $g(n)$, і вже точно не швидше.\n  - **Приклад:** $n = o(n^2)$, тому що $\\lim_{n \\to \\infty} \\frac{n}{n^2} = \\lim_{n \\to \\infty} \\frac{1}{n} = 0$.\n\n- **$\\omega$-нотація (Little Omega):**\n  - **Властивість:** $f(n) = \\omega(g(n))$ означає, що $f(n)$ росте **значно швидше**, ніж $g(n)$. Формально, $\\lim_{n \\to \\infty} \\frac{f(n)}{g(n)} = \\infty$.\n  - **Сутність:** Це строга нижня межа. Якщо $f(n) = \\omega(g(n))$, то $f(n) = \\Omega(g(n))$, але не навпаки. Це означає, що $f(n)$ ніколи не буде рости так само повільно, як $g(n)$, і вже точно не повільніше.\n  - **Приклад:** $n^2 = \\omega(n)$, тому що $\\lim_{n \\to \\infty} \\frac{n^2}{n} = \\lim_{n \\to \\infty} n = \\infty$.\n\n- **$O^*$ або $\\tilde{O}$ (Soft O):**\n  - **Властивість:** Ця нотація використовується для спрощення виразів асимптотичної складності шляхом **ігнорування логарифмічних факторів**. Якщо $f(n) = O(g(n) \\cdot \\log^k n)$ для деякого $k$, то ми можемо записати це як $f(n) = O^*(g(n))$ або $\\tilde{O}(g(n))$.\n  - **Сутність:** Логарифмічні фактори ростуть дуже повільно порівняно з поліноміальними або експоненціальними членами. У багатьох випадках, коли алгоритми мають логарифмічні множники (наприклад, сортування злиттям $O(n \\log n)$), ми хочемо зосередитися на більш значущих поліноміальних частинах. Soft O дозволяє абстрагуватися від цих логарифмічних деталей для більш високорівневого порівняння.\n  - **Приклад:** $O(n \\log n) = \\tilde{O}(n)$, $O(n \\log^2 n) = \\tilde{O}(n)$, $O(n^2 \\log n) = \\tilde{O}(n^2)$."
        }
    ]
}
