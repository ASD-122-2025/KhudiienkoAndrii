# %%
# Лабораторна робота №2
# Тема: Налагоджування та робота в середовищі Anaconda+Quarto
# Виконала: Худієнко Андрій
# Група: КН-24-1
# Дата: 10.03.2025

# 1. Завантаження та встановлення Anaconda

# 1.1 Завантаження
# Перейдіть на сайт Anaconda та завантажте дистрибутив для вашої операційної системи.
# (Інструкція: Відкрийте веб-браузер та перейдіть за посиланням https://www.anaconda.com/download/)

# 1.2 Встановлення
# Запустіть інсталятор.
# Оберіть "Install for: Just Me (Recommended)".
# Вкажіть шлях (C:\Users\ВашКористувач\Anaconda3).
# Додайте Anaconda до змінних середовища (PATH).
# Дочекайтеся завершення установки.

# Перевіримо встановлення:
import subprocess

def run_command(command):
    try:
        result = subprocess.run(command, shell=True, check=True, capture_output=True, text=True)
        print(result.stdout.strip())
    except subprocess.CalledProcessError as e:
        print(f"Помилка виконання команди: {e}")
        print(e.stderr.strip())

print("Перевірка версії conda:")
run_command("conda --version")
print("\nПеревірка версії python:")
run_command("python --version")

# 2. Створення віртуального середовища
# Після встановлення Anaconda створимо віртуальне середовище KhudiienkoAndrii_OpenCV.
print("\nСписок існуючих conda середовищ:")
run_command("conda env list")

# (Примітка: У вашому випадку вже існує середовище 'BoiaryntsovaPolina_OpenCV'. Його назву змінено на 'KhudiienkoAndrii_OpenCV' у цьому коді)
# Щоб створити нове середовище (якщо потрібно):
# !conda create --name KhudiienkoAndrii_OpenCV python=3.10
# Щоб активувати середовище:
# !conda activate KhudiienkoAndrii_OpenCV
# Щоб деактивувати середовище:
# !conda deactivate

# 3. Встановлення необхідних бібліотек
# Встановимо OpenCV, NumPy та Matplotlib у створене середовище.
print("\nСписок пакетів в активному середовищі (KhudiienkoAndrii_OpenCV):")
run_command("conda list -n KhudiienkoAndrii_OpenCV")

# (Примітка: Судячи зі списку, OpenCV, NumPy та Matplotlib вже встановлені у вашому середовищі)
# Щоб встановити пакети, якщо їх немає:
# !conda install -n KhudiienkoAndrii_OpenCV opencv-python numpy matplotlib

# Контрольні запитання та відповіді

print("\nКонтрольні запитання та відповіді:")

# 1. Що таке pip і conda та чим вони відрізняються між собою?
print("\n1. Що таке pip і conda та чим вони відрізняються між собою?")
print("pip – це стандартний менеджер пакетів Python, який використовується для встановлення та управління бібліотеками з PyPI (Python Package Index).")
print("conda – це менеджер пакетів та віртуальних середовищ, який входить до складу Anaconda. Він дозволяє встановлювати пакети як для Python, так і для інших мов програмування (наприклад, R).")
print("Основні відмінності:")
print("- pip працює лише з пакетами Python, conda підтримує інші типи пакетів.")
print("- conda керує залежностями більш ефективно, оскільки може встановлювати бібліотеки у форматах, що не потребують компіляції.")
print("- conda має вбудовані механізми для створення та управління віртуальними середовищами.")

# 2. Як виконати налаштування середовища за допомогою Virtualenv?
print("\n2. Як виконати налаштування середовища за допомогою Virtualenv?")
print("Virtualenv – це вбудований інструмент Python для створення ізольованих середовищ.")
print("Покрокова інструкція:")
print("- Встановити Virtualenv: pip install virtualenv")
print("- Створити нове середовище: virtualenv myenv")
print("- Активувати середовище: myenv\\Scripts\\activate (у Windows) або source myenv/bin/activate (у Linux/macOS)")
print("- Встановити необхідні пакети (наприклад, OpenCV): pip install opencv-python")
print("- Деактивувати середовище: deactivate")

# 3. Сфотографувати себе на телефон та імпортувати своє зображення у форматі .png на початок робочого зошита.
print("\n3. Сфотографувати себе на телефон та імпортувати своє зображення у форматі .png на початок робочого зошита.")
print("Кроки:")
print("- Перенести зображення у директорію з файлом .ipynb (наприклад, у папку images).")
print("- Додати зображення у Jupyter Notebook за допомогою Markdown: ![My Photo](images/my_photo.png)")
# (Примітка: Для відображення зображення файл 'images/my_photo.png' повинен існувати у тій же директорії, що і цей Python-файл або Jupyter Notebook)

# 4: Bubble Sort (Метод бульбашки)
print("\n4: Bubble Sort (Метод бульбашки)")
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

arr = [64, 34, 25, 12, 22, 11, 90]
bubble_sort(arr)
print("Відсортований масив:", arr)

# 5. Як виконати компіляцію вхідного документа Jupyter Notebook з його середовища, не використовуючи інтерфейс командного рядка?
print("\n5. Як виконати компіляцію вхідного документа Jupyter Notebook з його середовища, не використовуючи інтерфейс командного рядка?")
print("У Jupyter Notebook можна експортувати .ipynb у .html, .pdf або .md без використання командного рядка:")
print("- Відкрити Jupyter Notebook.")
print("- У верхньому меню натиснути File → Download as.")
print("- Обрати потрібний формат:")
print("  - HTML (.html)")
print("  - PDF via LaTeX (.pdf)")
print("  - Markdown (.md)")

# 6. Як виконати компіляцію Jupyter Notebook у HTML?
print("\n6. Як виконати компіляцію Jupyter Notebook у HTML?")
print("Для конвертації Jupyter Notebook у HTML можна використати:")
print("- Через командний рядок: jupyter nbconvert lab_2_KhudiienkoAndrii.ipynb --to html")
print("- За допомогою Quarto: quarto preview lab_2_KhudiienkoAndrii.ipynb")
# Out:
# Перевірка версії conda:
# conda 24.11.3
#
# Перевірка версії python:
# Python 3.13.2
#
# Список існуючих conda середовищ:
# # conda environments:
# #
# base                   C:\Users\andre\anaconda3
# Khudiienko_OpenCV    * C:\Users\andre\anaconda3\envs\Khudiienko_OpenCV
# myenv                  C:\Users\andre\anaconda3\envs\myenv
#                        D:\ProgramFiles\anaconda3
#
# Список пакетів в активному середовищі (KhudiienkoAndrii_OpenCV):
# Помилка виконання команди: Command 'conda list -n KhudiienkoAndrii_OpenCV' returned non-zero exit status 1.
# EnvironmentLocationNotFound: Not a conda environment: C:\Users\andre\anaconda3\envs\KhudiienkoAndrii_OpenCV
#
# Контрольні запитання та відповіді:
#
# 1. Що таке pip і conda та чим вони відрізняються між собою?
# pip – це стандартний менеджер пакетів Python, який використовується для встановлення та управління бібліотеками з PyPI (Python Package Index).
# ...
