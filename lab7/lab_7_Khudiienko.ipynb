# %%
# -*- coding: utf-8 -*-
"""
Лабораторна робота №7

Тема: Структури даних дерево, купа, геш-таблиця
Виконав: Худієнко Андрій
Група: КН-24-1
Дата: 31.05.2025
"""

# --- 1. Реалізація дерев за допомогою списків ---

# Приклад 1.1: Представлення дерева за допомогою списків
myTree = ['a', ['b', ['d',[],[]], ['e',[],[]] ], ['c', ['f',[],[]], []] ]
print(myTree)
print('left subtree = ', myTree[1])
print('root = ', myTree[0])
print('right subtree = ', myTree[2])
print(myTree[1][2][0])

# 1.2. Створення бінарного дерева та операції з ним:
# Задання вузла бінарного дерева
def BinaryTree(r):
    return [r, [], []]

# Додавання елемента у ліве піддерево
def insertLeft(root, newBranch):
    t = root.pop(1)
    if len(t) > 1:
        root.insert(1, [newBranch, t, []])
    else:
        root.insert(1, [newBranch, [], []])
    return root

# Додавання елемента у праве піддерево
def insertRight(root, newBranch):
    t = root.pop(2)
    if len(t) > 1:
        root.insert(2, [newBranch, [], t])
    else:
        root.insert(2, [newBranch, [], []])
    return root

# Повернути значення кореневого елемента
def getRootVal(root):
    return root[0]

# Присвоєння нового значення кореневому елементу
def setRootVal(root, newVal):
    root[0] = newVal

# Повернути ліве піддерево
def getLeftChild(root):
    return root[1]

# Повернути праве піддерево
def getRightChild(root):
    return root[2]

# Приклад використання функцій для дерева на списках
r = BinaryTree(3)
insertLeft(r,4)
insertLeft(r,5)
insertRight(r,6)
insertRight(r,7)
l = getLeftChild(r)
print(l)
setRootVal(l,9)
print(r)
insertLeft(l,11)
print(r)
print(getRightChild(getRightChild(r)))

# 1.2. Створення бінарного дерева та операції з ним (класовий підхід):
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.value = key

class BinarySearchTree:
    def __init__(self
